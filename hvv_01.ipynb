# %% [markdown]
# <a href="https://colab.research.google.com/github/kr3ddy/hvv_data/blob/main/hvv_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/MyDrive/TechLabs/hvv_data
# Out:
# /content/drive/MyDrive/TechLabs/hvv_data

# %%
import pandas as pd

# %%
stop_times_df = pd.read_csv("stop_times.txt", low_memory=False)

# %%
stop_times_df.head()

# %%
stop_times_df["stop_id"].count()
# Out:
# 2674756

# %%
stop_times_df["stop_id"].value_counts()

# %%
stops_df = pd.read_csv("stops.txt")
stops_df.head()
# Out:
#                    stop_id  stop_code                           stop_name  \
# 0   de:02000:11001::100001        NaN                HBF/Mönckebergstraße
# 1  de:02000:10002:4:100009        NaN                    Hauptbahnhof/ZOB
# 2   de:02000:10003::100011        NaN  U S Berliner Tor (Beim Strohhause)
# 3   de:02000:10005::100012        NaN                   Borgfelder Straße
# 4   de:02000:10010::100018        NaN                           Hübbesweg
#
#    stop_desc   stop_lat   stop_lon  location_type  parent_station  \
# 0        NaN  53.551556  10.004337              0             NaN
# 1        NaN  53.552235  10.011294              0             NaN
# 2        NaN  53.553392  10.024147              0             NaN
# 3        NaN  53.554732  10.034456              0             NaN
# 4        NaN  53.554597  10.061131              0             NaN
#
#    wheelchair_boarding platform_code
# 0                    0           NaN
# 1                    0           NaN
# 2                    0           NaN
# 3                    0           NaN
# 4                    0           NaN

# %%
stops_df.loc[stops_df["stop_id"] == "de:02000:80026::800091"]
# Out:
#                      stop_id  stop_code   stop_name  stop_desc   stop_lat  \
# 1628  de:02000:80026::800091        NaN  Bf. Altona        NaN  53.551568
#
#       stop_lon  location_type  parent_station  wheelchair_boarding  \
# 1628  9.934221              0             NaN                    1
#
#      platform_code
# 1628           NaN

# %%
# stops_df.loc[stops_df["stop_id"] == "de:02000:10002:4:100009"]

# %%
# stops_df.loc[stops_df["stop_id"] == "de:02000:40002::400009"]

# %%
# stops_df.loc[stops_df["stop_id"] == "de:02000:10001::100132"]

# %%
# stops_df.loc[stops_df["stop_id"] == "de:02000:10092::100223"]

# %%
# merged_df = pd.merge(stop_times_df, stops_df, on="stop_id")
# merged_df.head()

# %%
# ordered_df = merged_df.sort_values(by=['trip_id', 'stop_sequence'])
# ordered_df.head(10)

# %%
leftjoin_df = stop_times_df.merge(stops_df, how='left', on='stop_id')
leftjoin_df
# Out:
#           trip_id arrival_time departure_time                   stop_id  \
# 0        32768704      5:35:00        5:35:00         de:01061:46701::3
# 1        32768704      5:36:00        5:36:00         de:01061:46672::2
# 2        32768704      5:38:00        5:38:00        de:01061:106399::2
# 3        32768704      5:40:00        5:40:00         de:01061:46695::1
# 4        32768704      5:42:00        5:42:00         de:01061:46675::2
# ...           ...          ...            ...                       ...
# 2674751  35989126     25:16:24       25:17:42       de:01060:37992:1:99
# 2674752  35989126     25:20:24       25:20:42  de:01060:37993:1:8007055
# 2674753  35989126     25:23:24       25:23:42     de:01060:8007148:1:99
# 2674754  35989126     25:24:54       25:25:12  de:01060:37974:1:8007203
# 2674755  35989126     25:27:54       25:27:54       de:01060:37960:1:99
#
#          stop_sequence  pickup_type  drop_off_type stop_headsign  stop_code  \
# 0                    0            0              0           NaN        NaN
# 1                    1            0              0           NaN        NaN
# 2                    2            0              0           NaN        NaN
# 3                    3            0              0           NaN        NaN
# 4                    4            0              0           NaN        NaN
# ...                ...          ...            ...           ...        ...
# 2674751              2            0              0           NaN        NaN
# 2674752              3            0              0           NaN        NaN
# 2674753              4            0              0           NaN        NaN
# 2674754              5            0              0           NaN        NaN
# 2674755              6            0              0           NaN        NaN
#
#                            stop_name  stop_desc   stop_lat  stop_lon  \
# 0                       Itzehoe, ZOB        NaN  53.922988  9.515771
# 1        Bf. Itzehoe (Adenauerallee)        NaN  53.923393  9.511316
# 2                   Itzehoe, Rathaus        NaN  53.919152  9.515602
# 3                Itzehoe, Bergstraße        NaN  53.921271  9.522264
# 4              Oelixdorf, Amönenhöhe        NaN  53.913566  9.547643
# ...                              ...        ...        ...       ...
# 2674751                  Lentföhrden        NaN  53.876897  9.889825
# 2674752                       Nützen        NaN  53.863657  9.916738
# 2674753                     dodenhof        NaN  53.844396  9.939684
# 2674754                Holstentherme        NaN  53.839925  9.946071
# 2674755                Kaltenkirchen        NaN  53.834404  9.966818
#
#          location_type  parent_station  wheelchair_boarding platform_code
# 0                    0             NaN                    0           NaN
# 1                    0             NaN                    0           NaN
# 2                    0             NaN                    0           NaN
# 3                    0             NaN                    0           NaN
# 4                    0             NaN                    0           NaN
# ...                ...             ...                  ...           ...
# 2674751              0             NaN                    1           NaN
# 2674752              0             NaN                    1           NaN
# 2674753              0             NaN                    1           NaN
# 2674754              0             NaN                    1           NaN
# 2674755              0             NaN                    1           NaN
#
# [2674756 rows x 17 columns]

# %%
clean_df = leftjoin_df.drop(["pickup_type", "drop_off_type", "stop_headsign", "stop_code", "stop_desc", "location_type", "parent_station", "wheelchair_boarding", "platform_code", "arrival_time", "departure_time"], axis = 1)

# %%
clean_df = clean_df[["trip_id", "stop_sequence", "stop_id", "stop_name", "stop_lat", "stop_lon" ]]
clean_df
# Out:
#           trip_id  stop_sequence                   stop_id  \
# 0        32768704              0         de:01061:46701::3
# 1        32768704              1         de:01061:46672::2
# 2        32768704              2        de:01061:106399::2
# 3        32768704              3         de:01061:46695::1
# 4        32768704              4         de:01061:46675::2
# ...           ...            ...                       ...
# 2674751  35989126              2       de:01060:37992:1:99
# 2674752  35989126              3  de:01060:37993:1:8007055
# 2674753  35989126              4     de:01060:8007148:1:99
# 2674754  35989126              5  de:01060:37974:1:8007203
# 2674755  35989126              6       de:01060:37960:1:99
#
#                            stop_name   stop_lat  stop_lon
# 0                       Itzehoe, ZOB  53.922988  9.515771
# 1        Bf. Itzehoe (Adenauerallee)  53.923393  9.511316
# 2                   Itzehoe, Rathaus  53.919152  9.515602
# 3                Itzehoe, Bergstraße  53.921271  9.522264
# 4              Oelixdorf, Amönenhöhe  53.913566  9.547643
# ...                              ...        ...       ...
# 2674751                  Lentföhrden  53.876897  9.889825
# 2674752                       Nützen  53.863657  9.916738
# 2674753                     dodenhof  53.844396  9.939684
# 2674754                Holstentherme  53.839925  9.946071
# 2674755                Kaltenkirchen  53.834404  9.966818
#
# [2674756 rows x 6 columns]

# %%
# calculate the distance between two points using geopy
from geopy.distance import distance

point1 = (53.922988,9.515771)
point2 = (53.923393,9.511316)

print(distance(point1, point2).km)
# Out:
# 0.2961286822737724
